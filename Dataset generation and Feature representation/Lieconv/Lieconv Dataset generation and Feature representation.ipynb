# %%
#Importing the Lieconv dataset
from Lieconvdataset import *
from torch.utils.data import DataLoader

datasets, num_species, charge_scale = Tgdatasets()
# Out:
# D:\Anaconda3\envs\lieconv\lib\site-packages\lie_conv-0.1-py3.8.egg\corm_data\prepare\process.py:221: SyntaxWarning: "is" with a literal. Did you mean "=="?
# D:\Anaconda3\envs\lieconv\lib\site-packages\lie_conv-0.1-py3.8.egg\corm_data\prepare\process.py:223: SyntaxWarning: "is" with a literal. Did you mean "=="?
# D:\Anaconda3\envs\lieconv\lib\site-packages\lie_conv-0.1-py3.8.egg\corm_data\prepare\process.py:225: SyntaxWarning: "is" with a literal. Did you mean "=="?
# D:\Anaconda3\envs\lieconv\lib\site-packages\lie_conv-0.1-py3.8.egg\corm_data\prepare\process.py:238: SyntaxWarning: "is" with a literal. Did you mean "=="?
# D:\Anaconda3\envs\lieconv\lib\site-packages\lie_conv-0.1-py3.8.egg\corm_data\prepare\process.py:221: SyntaxWarning: "is" with a literal. Did you mean "=="?
# D:\Anaconda3\envs\lieconv\lib\site-packages\lie_conv-0.1-py3.8.egg\corm_data\prepare\process.py:223: SyntaxWarning: "is" with a literal. Did you mean "=="?
# ...

# %%
datasets['train'][6]['positions']
# Out:
# tensor([[  1.9946,   5.7011,  -0.1613],
#         [  1.9985,   5.1695,  -0.7736],
#         [  1.9462,   3.7645,  -0.5841],
#         [  3.0303,   2.9652,  -0.4446],
#         [  2.9853,   1.5798,  -0.2585],
#         [  1.7350,   1.0255,  -0.2192],
#         [  0.5779,   1.8028,  -0.3578],
#         [  0.6864,   3.1570,  -0.5381],
#         [  4.1917,   0.8685,  -0.1170],
#         [  4.3987,  -0.5105,  -0.1201],
#         [  3.4081,  -1.2618,  -0.2706],
#         [  5.6929,  -1.1789,   0.0385],
#         [  6.8358,  -0.4977,   0.3872],
#         [  8.0761,  -1.1353,   0.5358],
#         [  8.1856,  -2.4886,   0.3323],
#         [  7.0488,  -3.1809,  -0.0171],
#         [  5.8198,  -2.5471,  -0.1640],
#         [  9.4804,  -3.1216,   0.4937],
#         [ 10.5368,  -2.5422,   0.8092],
#         [  9.5857,  -4.0126,   0.3659],
#         [ -0.6986,   1.1257,  -0.3011],
#         [ -0.7890,  -0.1104,  -0.1304],
#         [ -1.9026,   1.8132,  -0.4340],
# ...

# %%
datasets['train'][6]['tg']
# Out:
# tensor(178.)
